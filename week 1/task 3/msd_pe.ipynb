# %%
import numpy as np
import matplotlib.pyplot as plt

t, msd = np.loadtxt("msd_20.0.dat", unpack=True)
plt.plot(t, msd)
plt.xlabel("time")
plt.ylabel("MSD")
plt.show()

# %%
t, msd = np.loadtxt("msd_40.0.dat", unpack=True)
plt.plot(t, msd)
plt.xlabel("time")
plt.ylabel("MSD")
plt.show()

# %%
t, msd = np.loadtxt("msd_60.0.dat", unpack=True)
plt.plot(t, msd)
plt.xlabel("time")
plt.ylabel("MSD")
plt.show()

# %%
t, msd = np.loadtxt("msd_80.0.dat", unpack=True)
plt.plot(t, msd)
plt.xlabel("time")
plt.ylabel("MSD")
plt.show()

# %%
t, msd = np.loadtxt("msd_120.0.dat", unpack=True)
plt.plot(t, msd)
plt.xlabel("time")
plt.ylabel("MSD")
plt.show()
